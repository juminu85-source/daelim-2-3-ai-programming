# %% [markdown]
# ## 통합 데이터 불러오기와 문자열 정리

# %%
df = pd.read_csv(r'C:\Users\jumin\Downloads\integrated_student_data.csv')

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\jumin\Downloads\integrated_student_data.csv')

# %%
df['name'] = df['name'].str.strip()

# %%
df['name'] = df['name'].str.strip().str.lower()

# %%
df[['first_name', 'last_name']] = df['name'].str.split(' ', expand=True)

# %%
df['domain'] = df['email'].str.split('@').str[1]

# %%
df['final_score'] = (df['assignment_score'] + df['quiz_avg'] + df['project_score']) / 3

# %%
df['achievement_level'] = df['final_score'].apply(
    lambda x: 'A' if x >= 85 else 'B' if x >= 70 else 'C'
)

# %%
df['final_score'] = (df['assignment_score'] + df['quiz_avg'] + df['project_score']) / 3

# %%
df[['student_id', 'name', 'email', 'domain', 'final_score', 'achievement_level']]
df.head(5)
# Out:
#   student_id      name                  email  study_hours  attendance  \
# 0        B01  kim hana  HANA.KIM@DAELIM.AC.KR          1.5          55
# 1        B02   lee min  lee.min@daelim.ac.kr           2.0          62
# 2        B03  park jun     park.jun@email.com          2.5          68
# 3        B04  choi seo  CHOI.SEO@DAELIM.AC.KR          3.0          72
# 4        B05  jung woo  jung.woo@daelim.ac.kr          3.5          74
#
#    assignment_score  quiz_avg  project_score  pass_fail first_name last_name  \
# 0                48        52             45          0        kim      hana
# 1                58        57             54          0        lee       min
# 2                61        63             60          0       park       jun
# 3                65        67             66          1       choi       seo
# 4                72        70             69          1       jung       woo
#
#           domain  final_score achievement_level
# ...

# %% [markdown]
# ## pandas 통합 분석과 이미지 해석

# %%
print ahievement_level = student(numbers);
# Out:
#   Cell In[21], line 1
#     print ahievement_level = student(numbers);
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %% [markdown]
# ## 머신러닝 예측과 산점도 해석

# %%
x = df[['study_hours', 'attendance', 'assignment_score', 'quiz_avg', 'project_score']]
y = pass_fail
model.score(X, y)

plt.figure(figsize=(8,5))
# s 매개변수는 점의 크기
plt.scatter(study, score, color="darkorange", s=80)
plt.title("공부 시간과 시험 점수의 관계")
plt.xlabel("공부 시간(h)")
plt.ylabel("시험 점수")
plt.grid(True)
plt.show()

# %% [markdown]
# ## 통합 시각화 재현과 분석
